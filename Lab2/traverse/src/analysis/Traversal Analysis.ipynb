# %% [markdown]
# Traverse.py Muti-Collection Analysis
# ====================================
#
# In this notebook, we will be performing analyses on a number of comma-separated values files generated by `traverse.py`.
#
# ### First, grab the csv files from my Git repo.
#
# All of the CSV data files are stored on my GitHub repository at http://github.com/hawkw/traverse, in the `data/` directory. The `data/datafiles.csv` file contains a listing of the available datafiles (as well as some additional metadata). We're going to use the paths stored in that file to access the individual data files.

# %%
import io, urllib2, bz2, pandas

# Get the metadata CSV that contains the listing of all runs
csvData = pandas.read_csv('https://raw.github.com/hawkw/traverse/master/data/datafiles.csv') 

datafiles = {}

# Loop through the filenames column and grab each filename.
for filename in csvData['Filename']:
    
    url = 'https://raw.github.com/hawkw/traverse/master/data/' + filename
    
    try:
        response = urllib2.urlopen(url).read()
    except Exception as e:
        print ("Caught HTTPError while accessing", e, url)
    else:
        try:
            data = bz2.decompress(response)
            datafiles[filename] = pandas.read_csv(io.BytesIO(data))
            print("Successfully decompressed " + filename)
        except Exception as e:
            print("Caught error \"{0}\" at {1}".format(e,url))
            print(e)
# Out:
# Successfully decompressed Users-Owner_2014-02-05.csv.bz2
# Successfully decompressed Users-will_2014-02-05.csv.bz2
# Successfully decompressed home-w-weismanm_2014-02-06.csv.bz2
# Successfully decompressed home-c-clivem_2014-02-07.csv.bz2
# Successfully decompressed home-b-blaken_2014-02-07.csv.bz2
# Successfully decompressed home-royokou_2014-02-08.csv.bz2
# Successfully decompressed home-royokou2_2014-02-08.csv.bz2
# Successfully decompressed home-royokou3_2014-02-08.csv.bz2
# Successfully decompressed Users-hawk_2014-02-09.csv.bz2
# Successfully decompressed Users-dibyo_2014-02-09.csv.bz2
# Caught error "Passed header=0 but only 0 lines in file" at https://raw.github.com/hawkw/traverse/master/data/Users-redbassett_2014-02-09.csv.bz2
# Passed header=0 but only 0 lines in file
# Successfully decompressed home-c-craftf_2014-02-10.csv.bz2
# Successfully decompressed home-k-kellyg_2014-02-12.csv.bz2
# Successfully decompressed home-k-kellyg_2014-02-12.csv.bz2

# %%
# get all the machines self-reporting as "Darwin" (Mac OS X)
macs = csvData[csvData['Platform'] == 'darwin']

# get all the machines self-reporting as "Linux2" (Ubuntu)
ubuntus = csvData[csvData['Platform'] == 'linux2']

# %% [markdown]
# Start graphing
# --------------
#
# Now that we've got our dataset, we can start doing some plotting

# %%
# set up the environment for plotting
from scipy import stats
from pylab import *
from matplotlib import ticker
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# we're outputting PDF figures to my CS440 dir
figpath = "/Users/hawk/Documents/DOCUMENTS/School/2014S/CMPSC440/Lab2/figures/"

# %%
mac_sizes = []
ubuntu_sizes = []
    
for key, value in datafiles.items():
    if key in list(macs['Filename']):
        for size in value['st_size']:
            if size > 1:
                mac_sizes.append(size)
    elif key in list(ubuntus['Filename']):
        for size in value['st_size']:
            if size > 1:
                ubuntu_sizes.append(size)

# %%
with sns.palette_context("husl"):
    # Draw histograms for file size
    plt.figure(1, figsize=(10,6))
    bins = 20

    plt.hist(mac_sizes, bins=bins, log = True, alpha=.5, color="#6495ED", label='Mac OS X')
    
    plt.title('Distribution of file sizes on Mac OS X')
    plt.ylabel('Frequency (logarithmic)')
    plt.xlabel('File size (bytes)')
    plt.legend()
    
    plt.savefig(figpath + 'size_mac-hist.pdf')
    plt.savefig(figpath + 'size_mac-hist.pgf')
    plt.show()
    
    
    plt.figure(2, figsize=(10,6))
    plt.hist(ubuntu_sizes, bins=bins, log = True, alpha=.5, color="#F08080", label='Ubuntu');

    plt.title('Distribution of file sizes on Ubuntu')
    plt.ylabel('Frequency (logarithmic)')
    plt.xlabel('File size (bytes)')
    plt.legend()
    
    plt.savefig(figpath + 'size_ubuntu-hist.pdf')
    plt.savefig(figpath + 'size_ubuntu-hist.pgf')
    plt.show()
    
    # Draw a histogram of the whole dataset
    bins = 25
    plt.figure(2, figsize=(10,5))
        
    plt.hist((mac_sizes + ubuntu_sizes), bins = bins, log= True, alpha = .5)
    
    plt.title('Distribution of file sizes on all operating systems')
    plt.ylabel('Frequency (logarithmic)')
    plt.xlabel('File size (bytes)')
    
    plt.savefig(figpath + 'size_hist.pdf')
    plt.savefig(figpath + 'size_hist.pgf')
    plt.show()

# %%
mac_nlink = []
ubuntu_nlink = []
    
for key, value in datafiles.items():
    if key in list(macs['Filename']):
        for nlink in value['st_nlink']:
            if nlink > 1:
                mac_nlink.append(nlink)
    elif key in list(ubuntus['Filename']):
        for nlink in value['st_nlink']:
            if nlink > 1:
                ubuntu_nlink.append(nlink)
                
with sns.palette_context("husl"):
    # Draw histograms for link density
    plt.figure(3, figsize=(10,6))
    bins = 25

    plt.hist(mac_nlink, bins=bins, log = True, alpha=.5, color="#6495ED", label='Mac OS X')
    plt.title('Distribution of link density on Mac OS X')
    plt.ylabel('Frequency (logarithmic)')
    plt.xlabel('Number of links')
    plt.legend()
    
    plt.savefig(figpath + 'nlink_mac-hist.pdf')
    plt.savefig(figpath + 'nlink_mac-hist.pgf')
    plt.show()
    
    plt.figure(4, figsize=(10,6))
    
    plt.hist(ubuntu_nlink, bins=bins, log = True, alpha=.5, color="#F08080", label='Ubuntu');
    
    plt.title('Distribution of link density on Ubuntu')
    plt.ylabel('Frequency (logarithmic)')
    plt.xlabel('Number of links')
    plt.legend()
    
    plt.savefig(figpath + 'nlink_ubuntu-hist.pdf')
    plt.savefig(figpath + 'nlink_ubuntu-hist.pgf')
    plt.show()
    
    # Draw a histogram of the whole dataset
    plt.figure(5, figsize=(10,6))
    #bins = 50
    plt.title('Total distribution of link density on Mac OS X and Ubuntu')
        
    plt.hist((mac_nlink + ubuntu_nlink), bins = bins, log= True, alpha = .5)
    
    plt.ylabel('Frequency (logarithmic)')
    plt.xlabel('File size (bytes)')
    
    plt.savefig(figpath + 'nlink_hist.pdf')
    plt.savefig(figpath + 'nlink_hist.pgf')
    plt.show()

# %% [markdown]
# ### Do depth analyses
#
# We're gonna look at average filesystem depth. This is not a characteristic that was studied by the `stat` operation, but by the path of each object encountered. In order to look at depth, we need to merge the dataframes for each OS.

# %%
# merge the master dataframe, the macs, and the ubuntus
macs_dict = dict((key, value) for (key, value) in datafiles.items() if key in list(macs['Filename']))
ubuntus_dict = dict((key, value) for (key, value) in datafiles.items() if key in list(ubuntus['Filename']))

merged_macs    = pandas.concat(macs_dict)
merged_ubuntus = pandas.concat(ubuntus_dict)
merged_master  = pandas.concat(datafiles)

# print the merged dataframes (to check if it worked correctly)
print merged_macs
print merged_ubuntus
print merged_master
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 956880 entries, (Users-Owner_2014-02-05.csv.bz2, 0) to (Users-will_2014-02-05.csv.bz2, 210248)
# Data columns (total 11 columns):
# path        956880  non-null values
# st_mode     956880  non-null values
# st_ino      956880  non-null values
# st_dev      956880  non-null values
# st_nlink    956880  non-null values
# st_uid      956880  non-null values
# st_gid      956880  non-null values
# st_size     956880  non-null values
# st_atime    956880  non-null values
# st_mtime    956880  non-null values
# st_ctime    956880  non-null values
# dtypes: float64(3), int64(7), object(1)
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 276014 entries, (home-b-blaken_2014-02-07.csv.bz2, 0) to (home-w-weismanm_2014-02-06.csv.bz2, 10303)
# Data columns (total 11 columns):
# path        276014  non-null values
# st_mode     276014  non-null values
# st_ino      276014  non-null values
# st_dev      276014  non-null values
# st_nlink    276014  non-null values
# st_uid      276014  non-null values
# st_gid      276014  non-null values
# st_size     276014  non-null values
# st_atime    276014  non-null values
# st_mtime    276014  non-null values
# st_ctime    276014  non-null values
# dtypes: float64(3), int64(7), object(1)
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1232894 entries, (Users-Owner_2014-02-05.csv.bz2, 0) to (home-w-weismanm_2014-02-06.csv.bz2, 10303)
# Data columns (total 11 columns):
# path        1232894  non-null values
# st_mode     1232894  non-null values
# st_ino      1232894  non-null values
# st_dev      1232894  non-null values
# st_nlink    1232894  non-null values
# st_uid      1232894  non-null values
# st_gid      1232894  non-null values
# st_size     1232894  non-null values
# st_atime    1232894  non-null values
# st_mtime    1232894  non-null values
# st_ctime    1232894  non-null values
# dtypes: float64(3), int64(7), object(1)

# %% [markdown]
# ## Now, analyze the depths
#
# We're defining the *depth* of a path as the number of occurances of the `/` character in that path. This won't work on data collected from Windows, which uses `\` as the path separator, but it would be trivial to count occurances of `\` as well, if we have to process datasets from Windows.

# %%
# function for doing depth counts
def depth(dataframe):
    return [path.count('/') for path in dataframe['path']]

mac_depth = depth(merged_macs)
ubuntu_depth = depth(merged_ubuntus)
master_depth = depth(merged_master)

# %%
with sns.palette_context("husl"):
    # Draw histograms for depth
    plt.figure(5, figsize=(10,6))
    bins = 18

    plt.hist(mac_depth, bins=bins, alpha=.5, color="#6495ED", label="Mac OS X")
    
    plt.title('Distribution of filepath depth on Mac OS X')
    plt.ylabel('Frequency')
    plt.xlabel('Depth')
    plt.legend()
    
    plt.savefig(figpath + 'depth_mac-hist.pdf')
    plt.savefig(figpath + 'depth_mac-hist.pgf')
    plt.show()
    
    plt.figure(6, figsize=(10,6))
    
    plt.hist(ubuntu_depth, bins=bins, alpha=.5, color="#F08080", label='Ubuntu');
    
    plt.title('Distribution of filepath depth on Ubuntu')
    plt.ylabel('Frequency')
    plt.xlabel('Depth')
    plt.legend()
    
    plt.savefig(figpath + 'depth_ubuntu-hist.pdf')
    plt.savefig(figpath + 'depth_ubuntu-hist.pgf')
    plt.show()
    
    # Draw a histogram of the whole dataset
    plt.figure(7, figsize=(10,6))
    #bins  = 10
    plt.title('Total distribution of file path depth on all operating systems')
        
    plt.hist(master_depth, bins = bins, alpha = .5)
    #sns.distplot(double(master_depth), bins = bins)
    
    plt.ylabel('Frequency')
    plt.xlabel('Depth')
    plt.savefig(figpath + 'depth_hist.pdf')
    plt.savefig(figpath + 'depth_hist.pgf')
    plt.show()

# %% [markdown]
# Hunt for correlations
# =====================
#
# Now that we've got our dataset and we've looked at it's the density and distribution, it's time to actually start doing science. We're going to do this by looking for correlations between the variables we measured in the study (i.e. everything that's returned from a syscall to `stat()`) and a few computed variables, such as file age, that we can compute from the data we've collected.
#
# We'll start by using the `corrplot()` function from Seaborn to draw a heatmap showing us which pairwise interactions between variables are the most strongly correlated. We can use the heatmap to "target" interactions between variables for further investigation: we'll look at regressions between the variables which are the most strongly correlated.

# %%
#now make a "master" correlation plot
plt.figure(4, figsize=(10,10))
sns.corrplot(merged_master)
plt.title("Pairwise Correlations")
plt.savefig(figpath + 'corrplot-master.pdf')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-7ff33b9f5d16> in <module>()
#       1 #now make a "master" correlation plot
#       2 plt.figure(4, figsize=(10,10))
# ----> 3 sns.corrplot(merged_master)
#       4 plt.title("Pairwise Correlations")
#       5 plt.savefig(figpath + 'corrplot-master.pdf')
#
# //anaconda/lib/python2.7/site-packages/seaborn/linearmodels.pyc in corrplot(data, names, annot, sig_stars, sig_tail, sig_corr, cmap, cmap_range, cbar, diag_names, ax, **kwargs)
#     708     # Get p values with a permutation test
#     709     if annot and sig_stars:
# --> 710         p_mat = moss.randomize_corrmat(data.values.T, sig_tail, sig_corr)
#     711     else:
#     712         p_mat = None
#
# //anaconda/lib/python2.7/site-packages/moss/statistical.pyc in randomize_corrmat(a, tail, corrected, n_iter, random_seed, return_dist)
#     246     for i_i in range(n_iter):
#     247         perm_i = np.concatenate([rs.permutation(n_obs) + (v * n_obs)
# --> 248                                  for v in range(n_vars)])
#     249         a_i = flat_a[perm_i].reshape(n_vars, n_obs)
#     250         null_dist[..., i_i] = np.corrcoef(a_i)
#
# KeyboardInterrupt:

# %%
# make corrplots for the single-os dataframes as well
plt.figure(5, figsize=(10,10))
sns.corrplot(merged_macs)
plt.title("Pairwise Correlations (Mac OS X)")
plt.savefig(figpath + 'corrplot-mac.pdf')
plt.savefig(figpath + 'corrplot-mac.pgf')
plt.show()

plt.figure(6, figsize=(10,10))
sns.corrplot(merged_ubuntus)
plt.title("Pairwise Correlations (Ubuntu)")
plt.savefig(figpath + 'corrplot-ubuntu.pdf')
plt.savefig(figpath + 'corrplot-ubuntu.pgf')
plt.show()

# %% [markdown]
# Make "metrics tables"
# ---------------------
#
# We're gonna try and make a table showing mean size values.

# %%
print("st_size metrics\n---------------")
print("Mac OS X:")
print(merged_macs['st_size'].describe())
print("\nUbuntu:")
print(merged_ubuntus['st_size'].describe())
print("\nTotal:")
print(merged_master['st_size'].describe())
# Out:
# st_size metrics
# ---------------
# Mac OS X:
# count    9.568800e+05
# mean     2.738772e+05
# std      4.500786e+06
# min      0.000000e+00
# 25%      3.130000e+02
# 50%      2.262500e+03
# 75%      1.286500e+04
# max      1.766392e+09
# dtype: float64
# Ubuntu:
# count    2.760140e+05
# mean     4.690964e+05
# std      2.842560e+07
# min      0.000000e+00
# 25%      1.180000e+03
# 50%      4.096000e+03
# 75%      9.275750e+03
# max      1.173090e+10
# dtype: float64
# Total:
# count    1.232894e+06
# mean     3.175818e+05
# std      1.402221e+07
# min      0.000000e+00
# 25%      4.050000e+02
# 50%      2.989000e+03
# 75%      1.227700e+04
# max      1.173090e+10
# dtype: float64

# %%
print("st_nlink metrics\n---------------")
print("\nMac OS X:")
print(merged_macs['st_nlink'].describe())
print("\nUbuntu:")
print(merged_ubuntus['st_nlink'].describe())
print("\nTotal:")
print(merged_master['st_nlink'].describe())
# Out:
# st_nlink metrics
# ---------------
#
# Mac OS X:
# count    956880.000000
# mean          2.152924
# std          35.360418
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max       26760.000000
# dtype: float64
# Ubuntu:
# count    276014.000000
# mean          1.429467
# std           3.559488
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max         474.000000
# dtype: float64
# Total:
# count    1232894.000000
# mean           1.990960
# std           31.198756
# min            1.000000
# 25%            1.000000
# 50%            1.000000
# 75%            1.000000
# max        26760.000000
# dtype: float64

# %%
describe_string="mean:\t\t{mean}\nstd:\t\t{std}\nmin:\t\t\t{minimum}\nmax:\t\t\t{maximum}"

print("depth metrics\n---------------")
print("\nMac OS X:")
print(describe_string.format(
                             mean=np.mean(mac_depth), 
                             std=np.std(mac_depth), 
                             minimum=min(mac_depth), 
                             maximum=max(mac_depth)
                             )
      )
print("\nUbuntu:")
print(describe_string.format(
                             mean=np.mean(ubuntu_depth), 
                             std=np.std(ubuntu_depth), 
                             minimum=min(ubuntu_depth), 
                             maximum=max(ubuntu_depth)
                             )
      )
print("\nTotal:")
print(describe_string.format(
                             mean=np.mean(master_depth), 
                             std=np.std(master_depth), 
                             minimum=min(master_depth), 
                             maximum=max(master_depth)
                             )
      )
# Out:
# depth metrics
# ---------------
#
# Mac OS X:
# mean:		11.9223768916
# std:		3.30465251863
# min:			3
# max:			26
# Ubuntu:
# mean:		10.1810777714
# std:		3.28319768437
# min:			3
# max:			21
# Total:
# mean:		11.5325437548
# std:		3.37874706663
# min:			3
# max:			26

# %%
print("size metrics\n---------------")
print("\nMac OS X:")
print(describe_string.format(
                             mean=np.mean(mac_size), 
                             std=np.std(mac_size), 
                             minimum=np.amin(mac_size), 
                             maximum=np.amax(mac_size)
                             )
      )
print("\nUbuntu:")
print(describe_string.format(
                             mean=np.mean(ubuntu_size), 
                             std=np.std(ubuntu_size), 
                             minimum=np.amin(ubuntu_size), 
                             maximum=np.amax(ubuntu_size)
                             )
      )
print("\nTotal:")
print(describe_string.format(
                             mean=np.mean(master_size), 
                             std=np.std(master_size), 
                             minimum=np.amin(master_size), 
                             maximum=np.amax(master_size)
                             )
      )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ea258944577f> in <module>()
#       1 print("size metrics\n---------------")
#       2 print("\nMac OS X:")
# ----> 3 print(describe_string.format(
#       4                              mean=np.mean(mac_size),
#       5                              std=np.std(mac_size),
#
# NameError: name 'describe_string' is not defined
# size metrics
# ---------------
#
# Mac OS X:
